# %% [markdown]
# Predizendo o resultado do jogo da velha
#
# Dataset: https://archive.ics.uci.edu/dataset/101/tic+tac+toe+endgame

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from sklearn import preprocessing

# %%
# load tic-tac-toe data
data = pd.read_csv("tic-tac-toe.data", sep=",")
data.rename(columns={'x': 'top left', 'x.1': 'top middle', 'x.2': 'top right','x.3': 'middle left', 'o': 'middle middle', 'o.1' : 'middle right', 'x.4' : 'bottom left', 'o.2' : 'bottom middle', 'o.3':'bottom right','positive' : 'outcome'},inplace=True)

# %%
data.head(3)
# Out:
#   top left top middle top right middle left middle middle middle right  \
# 0        x          x         x           x             o            o
# 1        x          x         x           x             o            o
# 2        x          x         x           x             o            o
#
#   bottom left bottom middle bottom right   outcome
# 0           o             x            o  positive
# 1           o             o            x  positive
# 2           o             b            b  positive

# %%
data_new = pd.get_dummies(data.iloc[:,0:9])

# %%
data_new.head(3)
# Out:
#    top left_b  top left_o  top left_x  top middle_b  top middle_o  \
# 0       False       False        True         False         False
# 1       False       False        True         False         False
# 2       False       False        True         False         False
#
#    top middle_x  top right_b  top right_o  top right_x  middle left_b  ...  \
# 0          True        False        False         True          False  ...
# 1          True        False        False         True          False  ...
# 2          True        False        False         True          False  ...
#
#    middle right_x  bottom left_b  bottom left_o  bottom left_x  \
# 0           False          False           True          False
# 1           False          False           True          False
# 2           False          False           True          False
#
#    bottom middle_b  bottom middle_o  bottom middle_x  bottom right_b  \
# 0            False            False             True           False
# 1            False             True            False           False
# 2             True            False            False            True
#
#    bottom right_o  bottom right_x
# 0            True           False
# 1           False            True
# 2           False           False
#
# [3 rows x 27 columns]

# %%
data_final = pd.concat([data_new, data.iloc[:,9]],axis=1)

# %%
# Split data into training and test sets
train, test = train_test_split(data_final, test_size=0.3)

# %%
train.head()
# Out:
#      top left_b  top left_o  top left_x  top middle_b  top middle_o  \
# 590        True       False       False          True         False
# 35        False       False        True         False         False
# 251       False       False        True          True         False
# 612        True       False       False          True         False
# 225       False       False        True          True         False
#
#      top middle_x  top right_b  top right_o  top right_x  middle left_b  ...  \
# 590         False        False        False         True          False  ...
# 35           True        False        False         True          False  ...
# 251         False        False         True        False          False  ...
# 612         False        False         True        False          False  ...
# 225         False        False        False         True          False  ...
#
#      bottom left_b  bottom left_o  bottom left_x  bottom middle_b  \
# 590          False           True          False            False
# 35            True          False          False            False
# 251          False          False           True            False
# 612           True          False          False             True
# 225          False          False           True            False
#
#      bottom middle_o  bottom middle_x  bottom right_b  bottom right_o  \
# 590             True            False           False           False
# 35              True            False           False            True
# 251             True            False           False           False
# 612            False            False           False            True
# 225             True            False           False            True
#
#      bottom right_x   outcome
# 590            True  positive
# 35            False  positive
# 251            True  positive
# 612           False  positive
# 225           False  positive
#
# [5 rows x 28 columns]

# %%
#Applying logistic Regression model
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()

# %%
x_train = train.iloc[:, :-1]
y_train= train.iloc[:, -1]
x_test = test.iloc[:, :-1]
y_test= test.iloc[:, -1]
LR = LR.fit(x_train, y_train)

# %%
LR.score(x_train, y_train)
# Out:
# 0.9805680119581465

# %%
from sklearn import metrics
prob = LR.predict_proba(x_test)
predicted= LR.predict(x_test)

# %%
#Findind the accuracy using confusion matrix
print(metrics.accuracy_score(y_test, predicted))
print(metrics.confusion_matrix(y_test, predicted))
print(metrics.classification_report(y_test, predicted))
# Out:
# 0.9861111111111112
# [[101   4]
#  [  0 183]]
#               precision    recall  f1-score   support
#
#     negative       1.00      0.96      0.98       105
#     positive       0.98      1.00      0.99       183
#
#     accuracy                           0.99       288
#    macro avg       0.99      0.98      0.98       288
# weighted avg       0.99      0.99      0.99       288
